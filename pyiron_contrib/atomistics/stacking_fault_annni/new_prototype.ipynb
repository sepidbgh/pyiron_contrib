# %%
import numpy as np

from pyiron_base import GenericJob, DataContainer 
from pyiron_atomistics.atomistics.structure.has_structure import HasStructure
from pyiron_atomistics.lammps.potential import LammpsPotential, LammpsPotentialFile
from pyiron_atomistics import Project
# Out:
# /home/sepideh/miniconda3/envs/pyiron/lib/python3.10/site-packages/pkg_resources/__init__.py:123: PkgResourcesDeprecationWarning: NOT-A-GIT-REPOSITORY is an invalid version and will not be supported in a future release
#   warnings.warn(

# %%
import os

# %%
os.getcwd()
# Out:
# '/home/sepideh/SFE_Calculation/Mg'

# %%
class StackingFaultANNNI(GenericJob):
    def __init__(self, project, job_name):
        super().__init__(project, job_name)
        self.input = DataContainer(table_name="inputdata")
        self.output = DataContainer(table_name="output")
    
    @property
    def reference_structure(self):
        return self.input.reference_structure

    @reference_structure.setter
    def reference_structure(self, val):
        self.input.reference_structure = val
    
    @property
    def potential(self):
        return self.input.potential.df
    
    @potential.setter
    def potential(self, name):
        potential = LammpsPotentialFile().find_by_name(name)
        self.input.potential = LammpsPotential()
        self.input.potential.df = potential  
        self.input.potential_name = name
    
    def calc_anni(self, temperature, steps):
        self.input.temperature = temperature
        self.input.steps = steps

    def run_static(self):
        self.status.running = True
        energies = []
        volumes = []
        self._minimize_structure()
        self.sf_structures = self._create_sf_structures()
        lst = [self.minimum_structure, *self.sf_structures]
        # print(lst)
        for structure in lst:
            self._create_ref_job(structure)
            zerok_energy = self._calculate_0K_energy(structure)
            qh_energy, qh_volume = self._calculate_qh_energy_volume(structure)
            energies.append(zerok_energy + qh_energy)
            volumes.append(qh_volume)
        self.output["energy"] = energies
        self.output["volume"] = volumes
        
        if self.minimum_structure.get_symmetry().spacegroup["Number"] in range(195, 231,1):
            sfe = self._calculate_SFE_fcc(energies[0], energies[1], energies[2], volumes[0])
        else:
            sfe = self._calculate_SFE_hcp(energies[0], energies[1], energies[2], volumes[0])
        
        self.output["stacking_fault_energy"] = sfe
        self.status.collect = True
        self.run()
        
    def _create_hcp_structure(self, minimum_structure):
        supercell_size = round((len(minimum_structure)/4)**(1/3))
        a_fcc = minimum_structure.cell[0][0]/(supercell_size)
        a_hcp = (((a_fcc)**3)/(np.sqrt(3)* (np.sqrt(8/3))))**(1/3)
        element = minimum_structure.get_chemical_symbols()[0]
        hcp_struc = self.project.create.structure.bulk(element,crystalstructure="hcp",a = a_hcp).repeat(supercell_size)
        return hcp_struc

    def _create_fcc_structure(self, minimum_structure):
        supercell_size = round((len(minimum_structure)/2)**(1/3))
        a_hcp = minimum_structure.cell[0][0]/(supercell_size)
        c_over_a = minimum_structure.cell[2][2]/minimum_structure.cell[0][0]
        a_fcc = (((a_hcp)**3)*(np.sqrt(3)* (c_over_a)))**(1/3)
        element = minimum_structure.get_chemical_symbols()[0]
        fcc_struc= self.project.create.structure.bulk(element,crystalstructure="fcc", a=a_fcc, cubic=True).repeat(supercell_size)
        return  fcc_struc

    def _create_dhcp_structure(self, minimum_structure): 
        supercell_size = round((len(minimum_structure)/2)**(1/3))
        a_hcp = minimum_structure.cell[0][0]/(supercell_size)
        c_over_a = minimum_structure.cell[2][2]/minimum_structure.cell[0][0]
        element = minimum_structure.get_chemical_symbols()[0]
        dhcp_unitcell= self.project.create.structure.bulk(element,crystalstructure="hcp",a = a_hcp, covera= c_over_a, orthorhombic=False).repeat([1,1,2])
        new_pos=[]
        for i in range(len(dhcp_unitcell)):
            if i == 3 :
                pos = dhcp_unitcell.get_positions()[i] + [a_hcp/2, -((np.sqrt(3)/2)*a_hcp)/3, 0.0]
            else:
                pos = dhcp_unitcell.get_positions()[i] +[0.0, 0.0, 0.0]   
            new_pos.append(pos)
        dhcp_unitcell.set_positions(new_pos)
        dhcp_hcp_struc = dhcp_unitcell.repeat(supercell_size)
        return dhcp_hcp_struc
    
    def _minimize_structure(self):
        job_mini = self.project.create_job(pr.job_type.Lammps, job_name=f'lmp_mini_{self.job_name}')
        job_mini.structure =  self.input.reference_structure
        job_mini.potential =  self.input.potential_name
        job_mini.calc_minimize(pressure=0.0)
        job_mini.run(delete_existing_job=True)
        self.minimum_structure = job_mini.get_structure() 
    
    def _create_sf_structures(self):
        if self.minimum_structure.get_symmetry().spacegroup["Number"] in range(195, 231,1):
            SF_structure_1 = self._create_hcp_structure(self.minimum_structure)
            SF_structure_2 = self._create_dhcp_structure(SF_structure_1)
        else:
            SF_structure_1 = self._create_fcc_structure(self.minimum_structure)
            SF_structure_2 = self._create_dhcp_structure(self.minimum_structure)
        return SF_structure_1, SF_structure_2
    
    def _create_ref_job(self, structure):
        job_strain_template = self.project.create.job.Lammps(job_name=f'lmp_{self.job_name}',delete_existing_job=True)
        job_strain_template.potential = self.input.potential_name
        job_strain_template.structure = structure
        self.job_template = job_strain_template 
    
    def _calculate_0K_energy(self, structure):
        murn_strain = self.project.create.job.Murnaghan(job_name=f'Murn_{self.job_name}',delete_existing_job=True)
        murn_strain.ref_job = self.job_template
        murn_strain.run(delete_existing_job=True)
        return ((murn_strain["output/energy"])/len(structure))

    def _calculate_qh_energy_volume(self, structure):
        phono_strain = self.project.create.job.PhonopyJob(job_name=f'phono_{self.job_name}', delete_existing_job=True)
        phono_strain.ref_job = self.job_template
        quasi_strain = self.project.create.job.QuasiHarmonicJob(job_name=f'quasi_{self.job_name}', delete_existing_job=True)
        quasi_strain.ref_job = phono_strain
        quasi_strain.input["temperature_end"] = self.input.temperature
        quasi_strain.input["temperature_steps"] = self.input.steps
        quasi_strain.input["axes"]=["x","y","z"]
        # quasi_strain.input["strains"] = None
        quasi_strain.run(delete_existing_job=True)
        energy = (quasi_strain["output/free_energy"].T)/len(structure)
        volume = (quasi_strain["output/volumes"].T)/len(structure)
        return energy, volume
    
    def _calculate_SFE_hcp(self, E_ref_structure, E_SF_structure_1, E_SF_structure_2, V_ref_structure):
        Ahcp_T       = []
        del_free_eng_I1 = []
        del_free_eng_I2 = []
        SFE_T_I1 = []
        SFE_T_I2 = []
        covera = self.minimum_structure.cell[2][2]/self.minimum_structure.cell[0][0]
        for i in range(len(E_ref_structure)):
            min_index = E_ref_structure[i].argmin()
            Ahcp_T.append(((np.sqrt(3)/2)* ((4*V_ref_structure[i][min_index]/(np.sqrt(3)*covera))**(2/3))))
            del_free_eng_I1.append((2*(E_SF_structure_2[i][min_index]- E_ref_structure[i][min_index]))*1000)
            del_free_eng_I2.append(((E_SF_structure_1[i][min_index])+(2*E_SF_structure_2[i][min_index])-(3*E_ref_structure[i][min_index]))* 1000)
            SFE_T_I1.append(del_free_eng_I1[i] /Ahcp_T[i])
            SFE_T_I2.append(del_free_eng_I2[i] /Ahcp_T[i])
        return SFE_T_I1, SFE_T_I2

    def _calculate_SFE_fcc(E_ref_structure, E_SF_structure_1, E_SF_structure_2, V_ref_structure):
        Afcc_T       = []
        del_free_eng_I1 = []
        del_free_eng_I2 = []
        SFE_T_I1 = []
        SFE_T_I2 = []
        for i in range(len(E_ref_structure)):
            min_index = E_ref_structure[i].argmin()
            Afcc_T.append((np.sqrt(3)/4)* ((4*V_ref_structure[i][min_index])**(2/3)))
            del_free_eng_I1.append((2*(E_SF_structure_1[i][min_index]- E_ref_structure[i][min_index]))*1000)
            del_free_eng_I2.append(((E_SF_structure_1[i][min_index])+(2*E_SF_structure_2[i][min_index])-(3*E_ref_structure[i][min_index]))* 1000)
            SFE_T_I1.append(del_free_eng_I1[i] /Afcc_T[i])
            SFE_T_I2.append(del_free_eng_I2[i] /Afcc_T[i])
        return SFE_T_I1, SFE_T_I2   

    
    def collect_output(self):
        #self.collect_general_output()
        self.to_hdf()
    
    def to_hdf(self, hdf=None, group_name=None):
        super().to_hdf(hdf=hdf, group_name=group_name)
        self.input.to_hdf(self.project_hdf5)
        self.output.to_hdf(self.project_hdf5)

    def from_hdf(self, hdf=None, group_name=None):
        super().from_hdf(hdf=hdf, group_name=group_name)
        self.input.from_hdf(self.project_hdf5)
        self.output.from_hdf(self.project_hdf5)

# %%
pr = Project("prototype")

# %%
job = pr.create_job(job_type= StackingFaultANNNI, job_name="prototype", delete_existing_job=True)

# %%
job.reference_structure = pr.create.structure.bulk('Mg', a = 3.21, orthorhombic=False).repeat(2)

# %%
job.potential = '2009--Kim-Y-M--Mg-Al--LAMMPS--ipr1'

# %%
job.calc_anni(temperature=800, steps=5)

# %%
job.run()
# Out:
# The job prototype was saved and received the ID: 181142
# The job lmp_mini_prototype was saved and received the ID: 181143
# The job Murn_prototype was saved and received the ID: 181146
# The job Murn_prototype_0_9 was saved and received the ID: 181148
# The job Murn_prototype_0_92 was saved and received the ID: 181150
# The job Murn_prototype_0_94 was saved and received the ID: 181152
# The job Murn_prototype_0_96 was saved and received the ID: 181154
# The job Murn_prototype_0_98 was saved and received the ID: 181156
# The job Murn_prototype_1_0 was saved and received the ID: 181157
# The job Murn_prototype_1_02 was saved and received the ID: 181158
# The job Murn_prototype_1_04 was saved and received the ID: 181159
# The job Murn_prototype_1_06 was saved and received the ID: 181161
# The job Murn_prototype_1_08 was saved and received the ID: 181163
# The job Murn_prototype_1_1 was saved and received the ID: 181165
# The job quasi_prototype was saved and received the ID: 181170
# The job quasi_prototype_0_9 was saved and received the ID: 181173
# The job lmp_prototype_0 was saved and received the ID: 181175
# The job quasi_prototype_0_92 was saved and received the ID: 181179
# The job lmp_prototype_0 was saved and received the ID: 181180
# The job quasi_prototype_0_94 was saved and received the ID: 181181
# The job lmp_prototype_0 was saved and received the ID: 181182
# The job quasi_prototype_0_96 was saved and received the ID: 181185
# The job lmp_prototype_0 was saved and received the ID: 181187
# The job quasi_prototype_0_98 was saved and received the ID: 181192
# The job lmp_prototype_0 was saved and received the ID: 181194
# The job quasi_prototype_1_0 was saved and received the ID: 181198
# The job lmp_prototype_0 was saved and received the ID: 181199
# The job quasi_prototype_1_02 was saved and received the ID: 181203
# The job lmp_prototype_0 was saved and received the ID: 181205
# The job quasi_prototype_1_04 was saved and received the ID: 181209
# The job lmp_prototype_0 was saved and received the ID: 181211
# The job quasi_prototype_1_06 was saved and received the ID: 181215
# The job lmp_prototype_0 was saved and received the ID: 181217
# The job quasi_prototype_1_08 was saved and received the ID: 181221
# The job lmp_prototype_0 was saved and received the ID: 181222
# The job quasi_prototype_1_1 was saved and received the ID: 181226
# The job lmp_prototype_0 was saved and received the ID: 181228
# The job Murn_prototype was saved and received the ID: 181237
# The job Murn_prototype_0_9 was saved and received the ID: 181238
# The job Murn_prototype_0_92 was saved and received the ID: 181239
# The job Murn_prototype_0_94 was saved and received the ID: 181240
# The job Murn_prototype_0_96 was saved and received the ID: 181241
# The job Murn_prototype_0_98 was saved and received the ID: 181243
# The job Murn_prototype_1_0 was saved and received the ID: 181245
# The job Murn_prototype_1_02 was saved and received the ID: 181247
# The job Murn_prototype_1_04 was saved and received the ID: 181248
# The job Murn_prototype_1_06 was saved and received the ID: 181250
# The job Murn_prototype_1_08 was saved and received the ID: 181253
# The job Murn_prototype_1_1 was saved and received the ID: 181254
# The job quasi_prototype was saved and received the ID: 181259
# The job quasi_prototype_0_9 was saved and received the ID: 181262
# The job lmp_prototype_0 was saved and received the ID: 181265
# The job quasi_prototype_0_92 was saved and received the ID: 181270
# The job lmp_prototype_0 was saved and received the ID: 181273
# The job quasi_prototype_0_94 was saved and received the ID: 181278
# The job lmp_prototype_0 was saved and received the ID: 181280
# The job quasi_prototype_0_96 was saved and received the ID: 181281
# The job lmp_prototype_0 was saved and received the ID: 181285
# The job quasi_prototype_0_98 was saved and received the ID: 181289
# The job lmp_prototype_0 was saved and received the ID: 181292
# The job quasi_prototype_1_0 was saved and received the ID: 181297
# The job lmp_prototype_0 was saved and received the ID: 181300
# The job quasi_prototype_1_02 was saved and received the ID: 181304
# The job lmp_prototype_0 was saved and received the ID: 181307
# The job quasi_prototype_1_04 was saved and received the ID: 181312
# The job lmp_prototype_0 was saved and received the ID: 181315
# The job quasi_prototype_1_06 was saved and received the ID: 181316
# The job lmp_prototype_0 was saved and received the ID: 181318
# The job quasi_prototype_1_08 was saved and received the ID: 181323
# The job lmp_prototype_0 was saved and received the ID: 181327
# The job quasi_prototype_1_1 was saved and received the ID: 181331
# The job lmp_prototype_0 was saved and received the ID: 181334
# The job Murn_prototype was saved and received the ID: 181346
# The job Murn_prototype_0_9 was saved and received the ID: 181348
# The job Murn_prototype_0_92 was saved and received the ID: 181349
# The job Murn_prototype_0_94 was saved and received the ID: 181350
# The job Murn_prototype_0_96 was saved and received the ID: 181351
# The job Murn_prototype_0_98 was saved and received the ID: 181352
# The job Murn_prototype_1_0 was saved and received the ID: 181353
# The job Murn_prototype_1_02 was saved and received the ID: 181355
# The job Murn_prototype_1_04 was saved and received the ID: 181357
# The job Murn_prototype_1_06 was saved and received the ID: 181359
# The job Murn_prototype_1_08 was saved and received the ID: 181361
# The job Murn_prototype_1_1 was saved and received the ID: 181362
# The job quasi_prototype was saved and received the ID: 181366
# The job quasi_prototype_0_9 was saved and received the ID: 181369
# The job lmp_prototype_0 was saved and received the ID: 181370
# The job lmp_prototype_1 was saved and received the ID: 181373
# The job quasi_prototype_0_92 was saved and received the ID: 181379
# The job lmp_prototype_0 was saved and received the ID: 181381
# The job lmp_prototype_1 was saved and received the ID: 181382
# The job quasi_prototype_0_94 was saved and received the ID: 181388
# The job lmp_prototype_0 was saved and received the ID: 181389
# The job lmp_prototype_1 was saved and received the ID: 181391
# The job quasi_prototype_0_96 was saved and received the ID: 181394
# The job lmp_prototype_0 was saved and received the ID: 181395
# The job lmp_prototype_1 was saved and received the ID: 181396
# The job quasi_prototype_0_98 was saved and received the ID: 181402
# The job lmp_prototype_0 was saved and received the ID: 181404
# The job lmp_prototype_1 was saved and received the ID: 181406
# The job quasi_prototype_1_0 was saved and received the ID: 181412
# The job lmp_prototype_0 was saved and received the ID: 181414
# The job lmp_prototype_1 was saved and received the ID: 181416
# The job quasi_prototype_1_02 was saved and received the ID: 181422
# The job lmp_prototype_0 was saved and received the ID: 181424
# The job lmp_prototype_1 was saved and received the ID: 181426
# The job quasi_prototype_1_04 was saved and received the ID: 181431
# The job lmp_prototype_0 was saved and received the ID: 181432
# The job lmp_prototype_1 was saved and received the ID: 181433
# The job quasi_prototype_1_06 was saved and received the ID: 181438
# The job lmp_prototype_0 was saved and received the ID: 181440
# The job lmp_prototype_1 was saved and received the ID: 181442
# The job quasi_prototype_1_08 was saved and received the ID: 181448
# The job lmp_prototype_0 was saved and received the ID: 181450
# The job lmp_prototype_1 was saved and received the ID: 181452
# The job quasi_prototype_1_1 was saved and received the ID: 181458
# The job lmp_prototype_0 was saved and received the ID: 181459
# The job lmp_prototype_1 was saved and received the ID: 181461

# %%
job.output["stacking_fault_energy"]
# Out:
# ([0.9032931406393951,
#   0.8443928293184233,
#   0.7622439442326892,
#   0.6777173608887597,
#   0.5919657435566751],
#  [1.7979261580535408,
#   1.6791711748328728,
#   1.5136462391956806,
#   1.3433894277401448,
#   1.170707904485249])
